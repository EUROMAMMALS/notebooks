# %%
from sqlalchemy import create_engine
from sqlalchemy import inspect
from sqlalchemy import MetaData
from sqlalchemy import Table
from configparser import ConfigParser
from sqlalchemy import text
import csv
import pandas as pd
from difflib import SequenceMatcher
import dataframe_image as dfi

# %%
config = ConfigParser()
config.read("setting.ini")
dbsett = config["eurodeer_db"]
networks = ["eurodeer", "euroboar", "eurowildcat", "euroibex", "eurolynx", "eureddeer"]

# %%
def check_tables(data, first, second):
    if first in keys and second in keys:
        seq_match = SequenceMatcher(None, data[first], data[second])
        return seq_match.ratio()
    elif first not in keys and second not in keys:
        return None
    elif first not in keys:
        return -1
    else:
        return -2

# %% [markdown]
# For each network we check the lookup tables and save the output of the records as a string in a dictionary

# %%
output = {}
for net in networks:
    dbname = "{net}_db".format(net=net)
    db_connection_url = "postgresql://{us}:{pas}@{host}:{port}/{db}".format(us=dbsett['user'],
                                                                      pas=dbsett['password'],
                                                                      host=dbsett['host'],
                                                                      port=dbsett['port'],
                                                                      db=dbname
                                                                     )
    con = create_engine(db_connection_url)
    connection = con.connect()
    inspector = inspect(con)
    tables = inspector.get_table_names(schema="lu_tables")
    for tab in tables:
        meta = MetaData(schema="lu_tables")
        meta.reflect(bind=con)
        primary_col = meta.tables[f"lu_tables.{tab}"].primary_key.columns.values()[0].name
        if tab not in output.keys():
            output[tab] = {}           
        results = pd.read_sql_query(f"select * from lu_tables.{tab} order by {primary_col}", con)
        output[tab][net] = results.to_csv(index=False, sep=";")

# %% [markdown]
# We execute the comparison of previous outputs, for each tables we check between the networks. We calculate the ratio of differences and save them in a dictionary

# %%
results = {"tests": [
    "eurodeer-eureddeer",
    "eurodeer-euroboar",
    "eurodeer-eurowildcat",
    "eurodeer-eurolynx",
    "eurodeer-euroibex",
    "euroboar-eurowildcat",
    "euroboar-eurolynx",
    "euroboar-euroibex",
    "euroboar-eureddeer",
    "eurowildcat-eurolynx",
    "eurowildcat-euroibex",
    "eurowildcat-eureddeer",
    "eurolynx-euroibex",
    "eurolynx-eureddeer",
    "euroibex-eureddeer",
]}
for tab in output.keys():
    out = []
    keys = output[tab].keys()
    # eurodeer-eureddeer
    if "eurodeer" in keys and "eureddeer" in keys:
        seq_match = SequenceMatcher(None, output[tab]["eurodeer"], output[tab]["eureddeer"])
        out.append(seq_match.ratio())
    elif "eurodeer" not in keys and "eureddeer" not in keys:
        out.append(None)
    elif "eurodeer" not in keys:
        out.append(-1)
    else:
        out.append(-2)
    # eurodeer-euroboar
    if "eurodeer" in keys and "euroboar" in keys:
        seq_match = SequenceMatcher(None, output[tab]["eurodeer"], output[tab]["euroboar"])
        out.append(seq_match.ratio())
    elif "eurodeer" not in keys and "euroboar" not in keys:
        out.append(None)
    elif "eurodeer" not in keys:
        out.append(-1)
    else:
        out.append(-2)
    # eurodeer-eurowildcat
    if "eurodeer" in keys and "eurowildcat" in keys:
        seq_match = SequenceMatcher(None, output[tab]["eurodeer"], output[tab]["eurowildcat"])
        out.append(seq_match.ratio())
    elif "eurodeer" not in keys and "eurowildcat" not in keys:
        out.append(None)
    elif "eurodeer" not in keys:
        out.append(-1)
    else:
        out.append(-2)
    # eurodeer-eurolynx
    if "eurodeer" in keys and "eurolynx" in keys:
        seq_match = SequenceMatcher(None, output[tab]["eurodeer"], output[tab]["eurolynx"])
        out.append(seq_match.ratio())
    elif "eurodeer" not in keys and "eurolynx" not in keys:
        out.append(None)
    elif "eurodeer" not in keys:
        out.append(-1)
    else:
        out.append(-2)
    # eurodeer - euroibex
    if "eurodeer" in keys and "euroibex" in keys:
        seq_match = SequenceMatcher(None, output[tab]["eurodeer"], output[tab]["euroibex"])
        out.append(seq_match.ratio())
    elif "eurodeer" not in keys and "euroibex" not in keys:
        out.append(None)
    elif "eurodeer" not in keys:
        out.append(-1)
    else:
        out.append(-2)
    # euroboar - eurowildcat
    if "euroboar" in keys and "eurowildcat" in keys:
        seq_match = SequenceMatcher(None, output[tab]["euroboar"], output[tab]["eurowildcat"])
        out.append(seq_match.ratio())
    elif "euroboar" not in keys and "eurowildcat" not in keys:
        out.append(None)
    elif "euroboar" not in keys:
        out.append(-1)
    else:
        out.append(-2)
    # euroboar - eurolynx
    if "euroboar" in keys and "eurolynx" in keys:
        seq_match = SequenceMatcher(None, output[tab]["euroboar"], output[tab]["eurolynx"])
        out.append(seq_match.ratio())
    elif "euroboar" not in keys and "eurolynx" not in keys:
        out.append(None)
    elif "euroboar" not in output[tab].keys():
        out.append(-1)
    else:
        out.append(-2)
    # euroboar - euroibex
    if "euroboar" in keys and "euroibex" in keys:
        seq_match = SequenceMatcher(None, output[tab]["euroboar"], output[tab]["euroibex"])
        out.append(seq_match.ratio())
    elif "euroboar" not in keys and "euroibex" not in keys:
        out.append(None)
    elif "euroboar" not in keys:
        out.append(-1)
    else:
        out.append(-2)
    # euroboar - eureddeer
    if "euroboar" in keys and "eureddeer" in keys:
        seq_match = SequenceMatcher(None, output[tab]["euroboar"], output[tab]["eureddeer"])
        out.append(seq_match.ratio())
    elif "euroboar" not in keys and "eureddeer" not in keys:
        out.append(None)
    elif "euroboar" not in keys:
        out.append(-1)
    else:
        out.append(-2)
    # eurowildcat - eurolynx
    if "eurolynx" in keys and "eurowildcat" in keys:
        seq_match = SequenceMatcher(None, output[tab]["eurolynx"], output[tab]["eurowildcat"])
        out.append(seq_match.ratio())
    elif "eurolynx" not in keys and "eurowildcat" not in keys:
        out.append(None)
    elif "eurolynx" not in keys:
        out.append(-2)
    else:
        out.append(-1)
    # eurowildcat - euroibex
    if "eurowildcat" in keys and "euroibex" in keys:
        seq_match = SequenceMatcher(None, output[tab]["eurowildcat"], output[tab]["euroibex"])
        out.append(seq_match.ratio())
    elif "eurowildcat" not in keys and "euroibex" not in keys:
        out.append(None)
    elif "eurowildcat" not in keys:
        out.append(-2)
    else:
        out.append(-1)
    # eurowildcat - eureddeer
    if "eurowildcat" in keys and "eureddeer" in keys:
        seq_match = SequenceMatcher(None, output[tab]["eurowildcat"], output[tab]["eureddeer"])
        out.append(seq_match.ratio())
    elif "eurowildcat" not in keys and "eureddeer" not in keys:
        out.append(None)
    elif "eurowildcat" not in keys:
        out.append(-2)
    else:
        out.append(-1)
    # eurolynx - euroibex
    if "eurolynx" in keys and "euroibex" in keys:
        seq_match = SequenceMatcher(None, output[tab]["eurolynx"], output[tab]["euroibex"])
        out.append(seq_match.ratio())
    elif "eurolynx" not in keys and "euroibex" not in keys:
        out.append(None)
    elif "eurolynx" not in keys:
        out.append(-2)
    else:
        out.append(-1)
    # eurolynx - eureddeer
    if "eurolynx" in keys and "eureddeer" in keys:
        seq_match = SequenceMatcher(None, output[tab]["eurolynx"], output[tab]["eureddeer"])
        out.append(seq_match.ratio())
    elif "eurolynx" not in keys and "eureddeer" not in keys:
        out.append(None)
    elif "eurolynx" not in keys:
        out.append(-2)
    else:
        out.append(-1)
    # euroibex - eureddeer
    if "euroibex" in keys and "eureddeer" in keys:
        seq_match = SequenceMatcher(None, output[tab]["euroibex"], output[tab]["eureddeer"])
        out.append(seq_match.ratio())
    elif "euroibex" not in keys and "eureddeer" not in keys:
        out.append(None)
    elif "euroibex" not in keys:
        out.append(-2)
    else:
        out.append(-1)
    results[tab] = out

# %%
results = {"tests": [
    "eurodeer-eureddeer",
    "eurodeer-euroboar",
    "eurodeer-eurowildcat",
    "eurodeer-eurolynx",
    "eurodeer-euroibex",
    "euroboar-eurowildcat",
    "euroboar-eurolynx",
    "euroboar-euroibex",
    "euroboar-eureddeer",
    "eurowildcat-eurolynx",
    "eurowildcat-euroibex",
    "eurowildcat-eureddeer",
    "eurolynx-euroibex",
    "eurolynx-eureddeer",
    "euroibex-eureddeer",
]}
for tab in output.keys():
    out = []
    data = output[tab]
    keys = data.keys()
    out.append(check_tables(data, "eurodeer", "eureddeer"))
    out.append(check_tables(data, "eurodeer", "euroboar"))
    out.append(check_tables(data, "eurodeer", "eurowildcat"))
    out.append(check_tables(data, "eurodeer", "eurolynx"))
    out.append(check_tables(data, "eurodeer", "euroibex"))
    out.append(check_tables(data, "euroboar", "eurowildcat"))
    out.append(check_tables(data, "euroboar", "eurolynx"))
    out.append(check_tables(data, "euroboar", "euroibex"))
    out.append(check_tables(data, "euroboar", "eureddeer"))
    out.append(check_tables(data, "eurowildcat", "eurolynx"))
    out.append(check_tables(data, "eurowildcat", "euroibex"))
    out.append(check_tables(data, "eurowildcat", "eureddeer"))
    out.append(check_tables(data, "eurolynx", "euroibex"))
    out.append(check_tables(data, "eurolynx", "eureddeer"))
    out.append(check_tables(data, "euroibex", "eureddeer"))
    results[tab] = out

# %% [markdown]
# We add the dictionary to a Pandas dataframe

# %%
results_pd = pd.DataFrame.from_dict(results, orient="index")
results_pd.columns = results_pd.iloc[0]
results_pd = results_pd[1:]
results_pd.reset_index(inplace=True)

# %% [markdown]
# Print the dataframe setting a text gradient according the values.
#
# Values meaning:
# * None: that table is missing in both the network database
# * -1: the table is missing in the first network of comparison. For example in the column eurodeer-euroboar -1 means that table is missing in eurodeer
# * -2:  the table is missing in the second network of comparison. For example in the column eurodeer-euroboar -2 means that table is missing in euroboar

# %%
results_pd.style.text_gradient(
    cmap="RdYlGn",
    vmin=0,
    vmax=1,
    subset=[
        "eurodeer-eureddeer",
        "eurodeer-euroboar",
        "eurodeer-eurowildcat",
        "eurodeer-eurolynx",
        "eurodeer-euroibex",
        "euroboar-eurowildcat",
        "euroboar-eurolynx",
        "euroboar-euroibex",
        "euroboar-eureddeer",
        "eurowildcat-eurolynx",
        "eurowildcat-euroibex",
        "eurowildcat-eureddeer",
        "eurolynx-euroibex",
        "eurolynx-eureddeer",
        "euroibex-eureddeer",
    ]
)
# Out:
# <style type="text/css">
# #T_a46b8_row0_col1, #T_a46b8_row20_col10 {
#   color: #04703b;
# }
# #T_a46b8_row0_col2 {
#   color: #4eb15d;
# }
# ...

# %%
styled = results_pd.style.text_gradient(
    cmap="RdYlGn",
    vmin=0,
    vmax=1,
    subset=[
        "eurodeer-eureddeer",
        "eurodeer-euroboar",
        "eurodeer-eurowildcat",
        "eurodeer-eurolynx",
        "eurodeer-euroibex",
        "euroboar-eurowildcat",
        "euroboar-eurolynx",
        "euroboar-euroibex",
        "euroboar-eureddeer",
        "eurowildcat-eurolynx",
        "eurowildcat-euroibex",
        "eurowildcat-eureddeer",
        "eurolynx-euroibex",
        "eurolynx-eureddeer",
        "euroibex-eureddeer",
    ]
)
await dfi.export_async(styled, "/tmp/check_lu_table.png")

# %%
for table, nets in output.items():
    for network, values in nets.items():
        with open(f"output/{table}_{network}.csv", "w") as fil:
            fil.write(values)
