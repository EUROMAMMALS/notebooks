# %%
from sqlalchemy import create_engine
from sqlalchemy import inspect
from sqlalchemy import MetaData
from sqlalchemy import Table
from configparser import ConfigParser
from sqlalchemy import text
import csv
import pandas as pd
from difflib import SequenceMatcher

# %%
config = ConfigParser()
config.read("setting.ini")
dbsett = config["eurodeer_db"]
networks = ["eurodeer", "euroboar", "eurowildcat", "euroibex", "eurolynx",]

# %% [markdown]
# For each network we check the lookup tables and save the output of the records as a string in a dictionary

# %%
output = {}
for net in networks:
    dbname = "{net}_db".format(net=net)
    db_connection_url = "postgresql://{us}:{pas}@{host}:{port}/{db}".format(us=dbsett['user'],
                                                                      pas=dbsett['password'],
                                                                      host=dbsett['host'],
                                                                      port=dbsett['port'],
                                                                      db=dbname
                                                                     )
    con = create_engine(db_connection_url)
    connection = con.connect()
    inspector = inspect(con)
    tables = inspector.get_table_names(schema="lu_tables")
    for tab in tables:
        meta = MetaData(schema="lu_tables")
        meta.reflect(bind=con)
        primary_col = meta.tables[f"lu_tables.{tab}"].primary_key.columns.values()[0].name
        if tab not in output.keys():
            output[tab] = {}           
        results = pd.read_sql_query(f"select * from lu_tables.{tab} order by {primary_col}", con)
        output[tab][net] = results.to_csv(index=False, sep=";")

# %% [markdown]
# We execute the comparison of previous outputs, for each tables we check between the networks. We calculate the ratio of differences and save them in a dictionary

# %%
results = {"tests": ["eurodeer-euroboar", "eurodeer-eurowildcat", "eurodeer-eurolynx", "euroboar-eurowildcat", "euroboar-eurolynx", "eurowildcat-eurolynx"]}
for tab in output.keys():
    out = []
    # eurodeer-euroboar
    if "eurodeer" in output[tab].keys() and "euroboar" in output[tab].keys():
        seq_match = SequenceMatcher(None, output[tab]["eurodeer"], output[tab]["euroboar"])
        out.append(seq_match.ratio())
    elif "eurodeer" not in output[tab].keys() and "euroboar" not in output[tab].keys():
        out.append(None)
    elif "eurodeer" not in output[tab].keys():
        out.append(-1)
    else:
        out.append(-2)
    # eurodeer-eurowildcat
    if "eurodeer" in output[tab].keys() and "eurowildcat" in output[tab].keys():
        seq_match = SequenceMatcher(None, output[tab]["eurodeer"], output[tab]["eurowildcat"])
        out.append(seq_match.ratio())
    elif "eurodeer" not in output[tab].keys() and "eurowildcat" not in output[tab].keys():
        out.append(None)
    elif "eurodeer" not in output[tab].keys():
        out.append(-1)
    else:
        out.append(-2)
    # eurodeer-eurolynx
    if "eurodeer" in output[tab].keys() and "eurolynx" in output[tab].keys():
        seq_match = SequenceMatcher(None, output[tab]["eurodeer"], output[tab]["eurolynx"])
        out.append(seq_match.ratio())
    elif "eurodeer" not in output[tab].keys() and "eurolynx" not in output[tab].keys():
        out.append(None)
    elif "eurodeer" not in output[tab].keys():
        out.append(-1)
    else:
        out.append(-2)
    # euroboar - eurowildcat
    if "euroboar" in output[tab].keys() and "eurowildcat" in output[tab].keys():
        seq_match = SequenceMatcher(None, output[tab]["euroboar"], output[tab]["eurowildcat"])
        out.append(seq_match.ratio())
    elif "euroboar" not in output[tab].keys() and "eurowildcat" not in output[tab].keys():
        out.append(None)
    elif "euroboar" not in output[tab].keys():
        out.append(-1)
    else:
        out.append(-2)
    # euroboar - eurolynx
    if "euroboar" in output[tab].keys() and "eurolynx" in output[tab].keys():
        seq_match = SequenceMatcher(None, output[tab]["euroboar"], output[tab]["eurolynx"])
        out.append(seq_match.ratio())
    elif "euroboar" not in output[tab].keys() and "eurolynx" not in output[tab].keys():
        out.append(None)
    elif "euroboar" not in output[tab].keys():
        out.append(-1)
    else:
        out.append(-2)
    # eurowildcat - eurolynx
    if "eurolynx" in output[tab].keys() and "eurowildcat" in output[tab].keys():
        seq_match = SequenceMatcher(None, output[tab]["eurolynx"], output[tab]["eurowildcat"])
        out.append(seq_match.ratio())
    elif "eurolynx" not in output[tab].keys() and "eurowildcat" not in output[tab].keys():
        out.append(None)
    elif "eurolynx" not in output[tab].keys():
        out.append(-2)
    else:
        out.append(-1)
    results[tab] = out

# %% [markdown]
# We add the dictionary to a Pandas dataframe

# %%
results_pd = pd.DataFrame.from_dict(results, orient="index")
results_pd.columns = results_pd.iloc[0]
results_pd = results_pd[1:]
results_pd.reset_index(inplace=True)

# %% [markdown]
# Print the dataframe setting a text gradient according the values.
#
# Values meaning:
# * None: that table is missing in both the network database
# * -1: the table is missing in the first network of comparison. For example in the column eurodeer-euroboar -1 means that table is missing in eurodeer
# * -2:  the table is missing in the second network of comparison. For example in the column eurodeer-euroboar -2 means that table is missing in euroboar

# %%
results_pd.style.text_gradient(cmap="RdYlGn", vmin=0, vmax=1, subset=["eurodeer-euroboar", "eurodeer-eurowildcat", "eurodeer-eurolynx", "euroboar-eurowildcat", "euroboar-eurolynx", "eurowildcat-eurolynx"])
# Out:
# <style type="text/css">
# #T_adedc_row0_col1 {
#   color: #4eb15d;
# }
# #T_adedc_row0_col2, #T_adedc_row0_col3, #T_adedc_row0_col4, #T_adedc_row0_col5, #T_adedc_row2_col1, #T_adedc_row2_col2, #T_adedc_row2_col3, #T_adedc_row3_col2, #T_adedc_row3_col4, #T_adedc_row3_col6, #T_adedc_row4_col2, #T_adedc_row4_col4, #T_adedc_row4_col6, #T_adedc_row6_col1, #T_adedc_row6_col2, #T_adedc_row6_col3, #T_adedc_row11_col1, #T_adedc_row11_col2, #T_adedc_row11_col3, #T_adedc_row13_col1, #T_adedc_row13_col2, #T_adedc_row13_col5, #T_adedc_row13_col6, #T_adedc_row15_col1, #T_adedc_row15_col2, #T_adedc_row15_col3, #T_adedc_row16_col1, #T_adedc_row16_col2, #T_adedc_row16_col3, #T_adedc_row18_col1, #T_adedc_row18_col2, #T_adedc_row18_col3, #T_adedc_row19_col1, #T_adedc_row19_col2, #T_adedc_row19_col3, #T_adedc_row21_col1, #T_adedc_row21_col2, #T_adedc_row21_col3, #T_adedc_row22_col1, #T_adedc_row22_col2, #T_adedc_row22_col3, #T_adedc_row24_col2, #T_adedc_row24_col4, #T_adedc_row24_col6, #T_adedc_row25_col2, #T_adedc_row25_col3, #T_adedc_row25_col4, #T_adedc_row25_col5, #T_adedc_row26_col2, #T_adedc_row26_col3, #T_adedc_row26_col4, #T_adedc_row26_col5, #T_adedc_row27_col2, #T_adedc_row27_col3, #T_adedc_row27_col4, #T_adedc_row27_col5, #T_adedc_row28_col2, #T_adedc_row28_col3, #T_adedc_row28_col4, #T_adedc_row28_col5, #T_adedc_row29_col2, #T_adedc_row29_col4, #T_adedc_row29_col6 {
#   color: #a50026;
# }
# #T_adedc_row0_col6, #T_adedc_row2_col4, #T_adedc_row2_col5, #T_adedc_row2_col6, #T_adedc_row6_col4, #T_adedc_row6_col5, #T_adedc_row6_col6, #T_adedc_row11_col4, #T_adedc_row11_col5, #T_adedc_row11_col6, #T_adedc_row13_col4, #T_adedc_row15_col4, #T_adedc_row15_col5, #T_adedc_row15_col6, #T_adedc_row16_col4, #T_adedc_row16_col5, #T_adedc_row16_col6, #T_adedc_row18_col4, #T_adedc_row18_col5, #T_adedc_row18_col6, #T_adedc_row19_col4, #T_adedc_row19_col5, #T_adedc_row19_col6, #T_adedc_row21_col4, #T_adedc_row21_col5, #T_adedc_row21_col6, #T_adedc_row22_col4, #T_adedc_row22_col5, #T_adedc_row22_col6, #T_adedc_row24_col1, #T_adedc_row24_col3, #T_adedc_row24_col5, #T_adedc_row25_col1, #T_adedc_row26_col1, #T_adedc_row27_col1, #T_adedc_row28_col1, #T_adedc_row29_col1, #T_adedc_row29_col3, #T_adedc_row29_col5 {
#   color: #000000;
# }
# #T_adedc_row1_col1 {
#   color: #e9f6a1;
# }
# #T_adedc_row1_col2 {
#   color: #c41e27;
# }
# #T_adedc_row1_col3 {
#   color: #f7814c;
# }
# #T_adedc_row1_col4, #T_adedc_row1_col6 {
#   color: #b91326;
# }
# #T_adedc_row1_col5 {
#   color: #fba05b;
# }
# #T_adedc_row3_col1 {
#   color: #148e4b;
# }
# #T_adedc_row3_col3 {
#   color: #f47044;
# }
# #T_adedc_row3_col5 {
#   color: #f57547;
# }
# #T_adedc_row4_col1, #T_adedc_row7_col1, #T_adedc_row7_col3, #T_adedc_row7_col5, #T_adedc_row8_col1, #T_adedc_row8_col3, #T_adedc_row8_col5, #T_adedc_row9_col1, #T_adedc_row10_col1, #T_adedc_row14_col3, #T_adedc_row17_col5, #T_adedc_row23_col3, #T_adedc_row25_col6, #T_adedc_row27_col6, #T_adedc_row28_col6 {
#   color: #006837;
# }
# #T_adedc_row4_col3, #T_adedc_row4_col5 {
#   color: #026c39;
# }
# #T_adedc_row5_col1 {
#   color: #fee491;
# }
# #T_adedc_row5_col2 {
#   color: #e8f59f;
# }
# #T_adedc_row5_col3 {
#   color: #bfe47a;
# }
# #T_adedc_row5_col4 {
#   color: #fdb96a;
# }
# #T_adedc_row5_col5 {
#   color: #fdb163;
# }
# #T_adedc_row5_col6 {
#   color: #ddf191;
# }
# #T_adedc_row7_col2, #T_adedc_row7_col4, #T_adedc_row7_col6 {
#   color: #f26841;
# }
# #T_adedc_row8_col2, #T_adedc_row8_col4, #T_adedc_row8_col6 {
#   color: #fb9d59;
# }
# #T_adedc_row9_col2, #T_adedc_row9_col4 {
#   color: #b1de71;
# }
# #T_adedc_row9_col3, #T_adedc_row9_col5 {
#   color: #feeda1;
# }
# #T_adedc_row9_col6 {
#   color: #70c164;
# }
# #T_adedc_row10_col2, #T_adedc_row10_col4, #T_adedc_row10_col6 {
#   color: #15904c;
# }
# #T_adedc_row10_col3, #T_adedc_row10_col5, #T_adedc_row17_col3 {
#   color: #2aa054;
# }
# #T_adedc_row12_col1 {
#   color: #b9e176;
# }
# #T_adedc_row12_col2 {
#   color: #fece7c;
# }
# #T_adedc_row12_col3, #T_adedc_row17_col4 {
#   color: #08773f;
# }
# #T_adedc_row12_col4 {
#   color: #fcaa5f;
# }
# #T_adedc_row12_col5 {
#   color: #c7e77f;
# }
# #T_adedc_row12_col6 {
#   color: #fdc776;
# }
# #T_adedc_row13_col3 {
#   color: #5ab760;
# }
# #T_adedc_row14_col1 {
#   color: #f88c51;
# }
# #T_adedc_row14_col2, #T_adedc_row14_col6 {
#   color: #279f53;
# }
# #T_adedc_row14_col4 {
#   color: #f7844e;
# }
# #T_adedc_row14_col5 {
#   color: #f88950;
# }
# #T_adedc_row17_col1 {
#   color: #2da155;
# }
# #T_adedc_row17_col2 {
#   color: #3faa59;
# }
# #T_adedc_row17_col6 {
#   color: #07753e;
# }
# #T_adedc_row20_col1 {
#   color: #36a657;
# }
# #T_adedc_row20_col2 {
#   color: #0f8446;
# }
# #T_adedc_row20_col3 {
#   color: #0a7b41;
# }
# #T_adedc_row20_col4, #T_adedc_row20_col5 {
#   color: #57b65f;
# }
# #T_adedc_row20_col6 {
#   color: #04703b;
# }
# #T_adedc_row23_col1 {
#   color: #e14430;
# }
# #T_adedc_row23_col2, #T_adedc_row23_col6 {
#   color: #0d8044;
# }
# #T_adedc_row23_col4 {
#   color: #f36b42;
# }
# #T_adedc_row23_col5 {
#   color: #f57748;
# }
# #T_adedc_row26_col6 {
#   color: #91d068;
# }
# </style>
# <table id="T_adedc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >tests</th>
#       <th id="T_adedc_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_adedc_level0_col1" class="col_heading level0 col1" >eurodeer-euroboar</th>
#       <th id="T_adedc_level0_col2" class="col_heading level0 col2" >eurodeer-eurowildcat</th>
#       <th id="T_adedc_level0_col3" class="col_heading level0 col3" >eurodeer-eurolynx</th>
#       <th id="T_adedc_level0_col4" class="col_heading level0 col4" >euroboar-eurowildcat</th>
#       <th id="T_adedc_level0_col5" class="col_heading level0 col5" >euroboar-eurolynx</th>
#       <th id="T_adedc_level0_col6" class="col_heading level0 col6" >eurowildcat-eurolynx</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adedc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_adedc_row0_col0" class="data row0 col0" >lu_mortality_new</td>
#       <td id="T_adedc_row0_col1" class="data row0 col1" >0.828311</td>
#       <td id="T_adedc_row0_col2" class="data row0 col2" >-2</td>
#       <td id="T_adedc_row0_col3" class="data row0 col3" >-2</td>
#       <td id="T_adedc_row0_col4" class="data row0 col4" >-2</td>
#       <td id="T_adedc_row0_col5" class="data row0 col5" >-2</td>
#       <td id="T_adedc_row0_col6" class="data row0 col6" >None</td>
#     </tr>
#     <tr>
#       <th id="T_adedc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_adedc_row1_col0" class="data row1 col0" >lu_mortality</td>
#       <td id="T_adedc_row1_col1" class="data row1 col1" >0.557742</td>
#       <td id="T_adedc_row1_col2" class="data row1 col2" >0.064381</td>
#       <td id="T_adedc_row1_col3" class="data row1 col3" >0.231534</td>
#       <td id="T_adedc_row1_col4" class="data row1 col4" >0.042829</td>
#       <td id="T_adedc_row1_col5" class="data row1 col5" >0.277924</td>
#       <td id="T_adedc_row1_col6" class="data row1 col6" >0.040423</td>
#     </tr>
#     <tr>
#       <th id="T_adedc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_adedc_row2_col0" class="data row2 col0" >lu_action</td>
#       <td id="T_adedc_row2_col1" class="data row2 col1" >-2</td>
#       <td id="T_adedc_row2_col2" class="data row2 col2" >-2</td>
#       <td id="T_adedc_row2_col3" class="data row2 col3" >-2</td>
#       <td id="T_adedc_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_adedc_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_adedc_row2_col6" class="data row2 col6" >None</td>
#     </tr>
#     <tr>
#       <th id="T_adedc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_adedc_row3_col0" class="data row3 col0" >lu_activity_sensor_mode</td>
#       <td id="T_adedc_row3_col1" class="data row3 col1" >0.918100</td>
#       <td id="T_adedc_row3_col2" class="data row3 col2" >-2</td>
#       <td id="T_adedc_row3_col3" class="data row3 col3" >0.203822</td>
#       <td id="T_adedc_row3_col4" class="data row3 col4" >-2</td>
#       <td id="T_adedc_row3_col5" class="data row3 col5" >0.212625</td>
#       <td id="T_adedc_row3_col6" class="data row3 col6" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_adedc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_adedc_row4_col0" class="data
